# %% [markdown]
# ## Content
#
# ## 01. Import libraries
# ## 02. Import data
# ## 03. Exercise - Part 2

# %% [markdown]
# ## 01. Import libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Create path

path = r'C:\Users\Frederick\Documents\07-12-2023 Instacart Basket Analysis'

# %% [markdown]
# ## 02. Import data

# %%
# Import data for orders_products merged with new variables added

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_added_variables.pkl'))

# %% [markdown]
# ## 03. Exercise - Part 2

# %%
# Checking output of the ords_prods_merge dataframe

ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  user_order_number  \
# 0             0             0   2539329        1                  1
# 1             1             1   2398795        1                  2
# 2             2             2    473747        1                  3
# 3             3             3   2254736        1                  4
# 4             4             4    431534        1                  5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  ...  Unnamed: 0_y product_name  aisle_id department_id  \
# ...

# %%
# Q2. Find aggregated mean of 'user_order_number' column grouped by department_id 

ords_prods_merge.groupby('department_id').agg({'user_order_number': ['mean']})
# Out:
#               user_order_number
#                            mean
# department_id
# 1                     15.457838
# 2                     17.277920
# 3                     17.170395
# 4                     17.811403
# 5                     15.215751
# 6                     16.439806
# 7                     17.225802
# 8                     15.340650
# 9                     15.895474
# 10                    20.197148
# 11                    16.170638
# 12                    15.887671
# 13                    16.583536
# 14                    16.773669
# 15                    16.165037
# 16                    17.665606
# 17                    15.694469
# 18                    19.310397
# 19                    17.177343
# 20                    16.473447
# 21                    22.902379

# %% [markdown]
# ## Q3. The results for the entire dataframe contains the average for all 21 departments, where as the subset only contains the average for 8 departments. Also, the highest average in the subset is department_id 16 (19.46) but in the full dataframe, we can see that department_id 21 has the highest average of 22.90. Similarly, the lowest average in the subset is department_id 17 with 11.29 but in the full dataframe, department_id 5 has the lowest average (15.22).

# %%
# Q4.Create user id grouping, performed aggregate function and add to new column 'max order' to ords_prods_merge dataframe

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['user_order_number'].transform(np.max)
# Out:
# C:\Users\Frederick\AppData\Local\Temp\ipykernel_9272\1891934290.py:3: FutureWarning: The provided callable <function amax at 0x0000029214DB7C40> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['user_order_number'].transform(np.max)

# %%
# Q4.Create a loyalty flag for loyal customer

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\Frederick\AppData\Local\Temp\ipykernel_9272\151755974.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Loyal customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Q4.Create a loyalty flag for Regular customer

ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# Q4.Create a loyalty flag for New customer

ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking output on the new loyalty flags with user_id, loyalty_flag and user_order_number columns

ords_prods_merge[['user_id', 'loyalty_flag', 'user_order_number']].head(60)
# Out:
#     user_id      loyalty_flag  user_order_number
# 0         1      New customer                  1
# 1         1      New customer                  2
# 2         1      New customer                  3
# 3         1      New customer                  4
# 4         1      New customer                  5
# 5         1      New customer                  6
# 6         1      New customer                  7
# 7         1      New customer                  8
# 8         1      New customer                  9
# 9         1      New customer                 10
# 10       15  Regular customer                 15
# 11       15  Regular customer                 17
# 12       15  Regular customer                 18
# 13       15  Regular customer                 21
# 14       15  Regular customer                 22
# 15       19      New customer                  2
# 16       19      New customer                  5
# 17       19      New customer                  7
# ...

# %%
# Q5. Find aggregated mean of 'prices' column grouped by loyalty_flag 

ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ## Q5. From the above table, we can see that the spending habits are different for loyal customers to that of regular and new customers. Loyal customers tended to buy products with lower prices (average of 10.37) where as new customers tended to buy the more expensive products (average 13.29), followed by regular customers (average 12.50).

# %%
# Q6.Create user id grouping, performed aggregate function on prices and add to new column 'avg_price' to ords_prods_merge dataframe

ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\Frederick\AppData\Local\Temp\ipykernel_9272\2784604785.py:3: FutureWarning: The provided callable <function mean at 0x0000029214DBC9A0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Q6. Checking output on the new column 'avg_price'

ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  user_order_number  \
# 0              0             0   2539329        1                  1
# 1              1             1   2398795        1                  2
# 2              2             2    473747        1                  3
# 3              3             3   2254736        1                  4
# 4              4             4    431534        1                  5
# 5              5             5   3367565        1                  6
# 6              6             6    550135        1                  7
# 7              7             7   3108588        1                  8
# 8              8             8   2295261        1                  9
# 9              9             9   2550362        1                 10
# 10           144           144   2968173       15                 15
# 11           146           146   1870022       15                 17
# 12           147           147   1911383       15                 18
# ...

# %%
# Q6.Create a spending flag for low spender

ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'
# Out:
# C:\Users\Frederick\AppData\Local\Temp\ipykernel_9272\3557069658.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Low spender' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Q6.Create a spending flag for High spender

ords_prods_merge.loc[ords_prods_merge['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Checking output on the new spending flags with user_id, spending_flag and avg_price columns

ords_prods_merge[['user_id', 'spending_flag', 'avg_price']].head(100)
# Out:
#     user_id spending_flag  avg_price
# 0         1   Low spender   6.367797
# 1         1   Low spender   6.367797
# 2         1   Low spender   6.367797
# 3         1   Low spender   6.367797
# 4         1   Low spender   6.367797
# ..      ...           ...        ...
# 95      360  High spender  10.006250
# 96      377   Low spender   8.496552
# 97      387   Low spender   7.396610
# 98      420   Low spender   7.387805
# 99      420   Low spender   7.387805
#
# [100 rows x 3 columns]

# %%
# Q7.Create user id grouping, performed aggregate function on days_since_prior_order and add to new column 'median_days' to ords_prods_merge dataframe

ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\Frederick\AppData\Local\Temp\ipykernel_9272\3397459266.py:3: FutureWarning: The provided callable <function median at 0x0000029214EFA5C0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Q7. Checking output on the new column 'median_days_since_prior_order'

ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  user_order_number  \
# 0              0             0   2539329        1                  1
# 1              1             1   2398795        1                  2
# 2              2             2    473747        1                  3
# 3              3             3   2254736        1                  4
# 4              4             4    431534        1                  5
# 5              5             5   3367565        1                  6
# 6              6             6    550135        1                  7
# 7              7             7   3108588        1                  8
# 8              8             8   2295261        1                  9
# 9              9             9   2550362        1                 10
# 10           144           144   2968173       15                 15
# 11           146           146   1870022       15                 17
# 12           147           147   1911383       15                 18
# ...

# %%
# Q7.Create a frequency flag for Non-frequent customer

ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'
# Out:
# C:\Users\Frederick\AppData\Local\Temp\ipykernel_9272\1887152545.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Non-frequent customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
# Q7.Create a frequency flag for Regular customer

ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] <= 20) & (ords_prods_merge['median_days_since_prior_order'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
# Q7.Create a frequency flag for Frequent customer

ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Q7.Checking output on the new frequency flags with user_id, frequency_flag and median_days_since_prior_order columns

ords_prods_merge[['user_id', 'frequency_flag', 'median_days_since_prior_order']].head(60)
# Out:
#     user_id         frequency_flag  median_days_since_prior_order
# 0         1  Non-frequent customer                           20.5
# 1         1  Non-frequent customer                           20.5
# 2         1  Non-frequent customer                           20.5
# 3         1  Non-frequent customer                           20.5
# 4         1  Non-frequent customer                           20.5
# 5         1  Non-frequent customer                           20.5
# 6         1  Non-frequent customer                           20.5
# 7         1  Non-frequent customer                           20.5
# 8         1  Non-frequent customer                           20.5
# 9         1  Non-frequent customer                           20.5
# 10       15      Frequent customer                           10.0
# 11       15      Frequent customer                           10.0
# 12       15      Frequent customer                           10.0
# ...

# %%
# Assign missing values to suspected outliers in prices

ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
# Check max value on prices

ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_flags.pkl'))

# %%
# Check output for loyalty flag

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Check output for spending flag

ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
# Check output for frequency flag

ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64
